# %%
#import pandas module
import pandas as pd
import csv

# %%
imdb_prin =  'C:\\Users\\sheri\\Documents\\Application of AI, ML\\name.basics.tsv\\data.tsv'
imdb_n =  'C:\\Users\\sheri\\Documents\\Application of AI, ML\\name.basics.tsv\\name.tsv'
imdb_dfx =  'C:\\Users\\sheri\\Documents\\Application of AI, ML\\name.basics.tsv\\dfx.csv'

# %%
dfp = pd.read_csv(imdb_prin, sep ='\t',low_memory = False)

# %%
dfx = pd.read_csv(imdb_dfx,low_memory = False)

# %%
dfn = pd.read_csv(imdb_n, sep ='\t,low_memory = False)

# %%
dfn
# Out:
#              nconst         primaryName birthYear deathYear  \
# 0         nm0000001        Fred Astaire      1899      1987
# 1         nm0000002       Lauren Bacall      1924      2014
# 2         nm0000003     Brigitte Bardot      1934        \N
# 3         nm0000004        John Belushi      1949      1982
# 4         nm0000005      Ingmar Bergman      1918      2007
# ...             ...                 ...       ...       ...
# 10843398  nm9993714   Romeo del Rosario        \N        \N
# 10843399  nm9993716       Essias Loberg        \N        \N
# 10843400  nm9993717  Harikrishnan Rajan        \N        \N
# 10843401  nm9993718         Aayush Nair        \N        \N
# 10843402  nm9993719          Andre Hill        \N        \N
#
#                             primaryProfession  \
# 0              soundtrack,actor,miscellaneous
# 1                          actress,soundtrack
# 2         actress,soundtrack,music_department
# 3                     actor,soundtrack,writer
# ...

# %%
data = pd.merge(dfp, dfn, on ="nconst")

# %%
dataN = data[data['category'].isin(['director','actor','actress'])]
dataM = data[data['category'].isin(['actor','actress'])]
# def get_director(x):
#     for i in x:
#         if i['category'] == 'director':
#             return i['name']
#     return np.nan

# data3 = dataN['category'].apply(get_director)

dataD = dataN[dataN['category']=='director']
dataD
# Out:
#              tconst  ordering      nconst  category job characters  \
# 2         tt0000001         2   nm0005690  director  \N         \N
# 3         tt0000005         3   nm0005690  director  \N         \N
# 4         tt0000006         1   nm0005690  director  \N         \N
# 5         tt0000007         3   nm0005690  director  \N         \N
# 6         tt0000008         2   nm0005690  director  \N         \N
# ...             ...       ...         ...       ...  ..        ...
# 43990876  tt9916692         5  nm10538592  director  \N         \N
# 43990877  tt9916696         4  nm10529675  director  \N         \N
# 43990883  tt9916698         4  nm10439323  director  \N         \N
# 43990887  tt9916730         5  nm10538612  director  \N         \N
# 43990908  tt9916856         5  nm10538645  director  \N         \N
#
#                    primaryName birthYear deathYear  \
# 2         William K.L. Dickson      1860      1935
# 3         William K.L. Dickson      1860      1935
# ...

# %%
data2 = pd.merge(dfx, dataM[['tconst','category', 'primaryName']], on ="tconst")

# %%
data2
# Out:
#        Unnamed: 0    index     tconst  titleType          primaryName_x  \
# 0               0  1026645  tt6998518      movie                  Mandy
# 1               0  1026645  tt6998518      movie                  Mandy
# 2               0  1026645  tt6998518      movie                  Mandy
# 3               0  1026645  tt6998518      movie                  Mandy
# 4               1  1035201  tt7177814  tvEpisode  Castle Party Massacre
# ...           ...      ...        ...        ...                    ...
# 23007        5963  1098110  tt8737608      movie                   Rams
# 23008        5963  1098110  tt8737608      movie                   Rams
# 23009        5963  1098110  tt8737608      movie                   Rams
# 23010        5964  1105308  tt8945942      movie             Centigrade
# 23011        5964  1105308  tt8945942      movie             Centigrade
#
#                 originalName  isAdult  yearOfRelease  Duration  \
# ...

# %%
data3 = data2.groupby('tconst')['primaryName_y'].apply(list).reset_index(name = 'cast')

# %%
dataF = pd.merge(data3, dataD[['tconst','primaryName']], on='tconst')

# %%
dataG = dataF.groupby('tconst')['primaryName'].apply(list).reset_index(name = 'director(s)')

# %%
dataH = pd.merge(dataG, data3[['tconst', 'cast']], on='tconst')

# %%
dataH.to_csv('cast.csv')
#dataF

# %%
dataH
# Out:
#          tconst                          director(s)  \
# 0     tt0069049                       [Orson Welles]
# 1     tt0360556                      [Ramin Bahrani]
# 2     tt0365545                  [Haifaa Al-Mansour]
# 3     tt0427543                 [Sam Taylor-Johnson]
# 4     tt0437086                   [Robert Rodriguez]
# ...         ...                                  ...
# 5494  tt9913036  [Haruo Sotozaki, Shin'ya Shimomura]
# 5495  tt9913038           [Haruo Sotozaki, Yûki Itô]
# 5496  tt9913040     [Shûji Miyahara, Haruo Sotozaki]
# 5497  tt9913050   [Haruo Sotozaki, Masashi Takeuchi]
# 5498  tt9916362                       [Pablo Agüero]
#
#                                                    cast
# 0     [John Huston, Susan Strasberg, Peter Bogdanovi...
# 1     [Cindy Katz, Michael Shannon, Michael B. Jorda...
# 2     [Lynn Whitfield, Sanaa Lathan, Lyriq Bent, Ric...
# 3     [Giovanni Ribisi, Billy Bob Thornton, Aaron Ta...
# ...
